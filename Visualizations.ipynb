# %% [markdown]
# ## Visualization: using Pyplot module of Matplotlib
# Data visualization is the act of trying to understand data by placing it in a visual context so that patterns, trends and correlations that might not otherwise be detected can be exposed. With the aid of visualzation, insights are gotten from a dataset at a grasp as the aim of every visualization is to explain the hidden fact about the data.
#
# In Python, visualizations are done with matplotlib, seaborn and but not limited to Pandas. In this section, we'd be exploring creating visuals with matplotlib which is the most popular python visualization tools and it's built on MATLAB.

# %%
# Import the iris dataset 
import pandas as pd
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #### Installing and importing matplotlib
# Matplotlib is pre-installed if your using anaconda. But for thos using other container and matplolib is not installed,you can install and import as below

# %%
import matplotlib.pyplot as plt # This imports matplotlib and makes it ready for use

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
type(iris.PetalLengthCm)
# Out:
# pandas.core.series.Series

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Scatter plot

# %%
plt.scatter(iris.SepalLengthCm, iris.SepalWidthCm)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width (cm)')
plt.title('Iris Dataset; Sepal Length and Sepal Width')
plt.show()

# %% [markdown]
# Barchart

# %%
plt.bar(iris.Species, iris.SepalLengthCm)
plt.title('Bar plot of Species and Sepal Length (cm)')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %% [markdown]
# Histogram

# %%
plt.hist(iris.SepalWidthCm)
plt.title('Histogram showing Species and Sepal Width')
plt.xlabel('Species')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
plt.plot(iris.PetalLengthCm) #iris.PetalWidthCm)
#plt.scatter(iris.PetalLengthCm) #iris.PetalWidthCm)
plt.title('Line plot of Petal length and Petal Width')
plt.xlabel('Petal Lenght (cm)')
plt.ylabel('Petal Width (cm)')
plt.show()

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.shape[0]
# Out:
# 150

# %%
xlabel = range(0, iris.shape[0])
xlabel
# Out:
# range(0, 150)

# %%
plt.plot(range(0,iris.shape[0]), iris.PetalLengthCm)
#plt.scatter(iris.PetalLengthCm, iris.PetalWidthCm)
plt.title('Line plot of Petal length and Petal Width')
plt.xlabel('Petal Lenght (cm)')
plt.ylabel('Petal Width (cm)')
plt.show()

# %%
plt.plot(range(0,iris.shape[0]), iris.PetalWidthCm)
#plt.scatter(iris.PetalLengthCm, iris.PetalWidthCm)
plt.title('Line plot of Petal length and Petal Width')
plt.xlabel('Petal Lenght (cm)')
plt.ylabel('Petal Width (cm)')
plt.show()

# %%
columns = iris.drop(['Species', 'Id'], axis =1)
for column in columns:
    plt.plot(iris[column])
    plt.scatter(range(0, iris.shape[0]), iris[column])
plt.title('Line plot of Petal length and Petal Width')
plt.xlabel('Observation')
plt.ylabel('Features (cm)')
plt.legend()
plt.show()

# %%
plt.plot(iris.PetalLengthCm)
plt.plot(iris.PetalWidthCm)
plt.plot(iris.SepalLengthCm)
plt.plot(iris.SepalWidthCm)

# %% [markdown]
# ###### Using Subplot to create more than one graph in a figure:
# It might be necessary to create more than one graph in a single figure mostly for easy comparism and beyond. To achieve this, subplot helps

# %%
# plot a line, implicitly creating a subplot(111)
#plt.plot([1,2,3, 4, 5])
# now create a subplot which represents the top plot of a grid
# with 2 rows and 1 column. Since this subplot will overlap the
# first, the plot (and its axes) previously created, will be removed
plt.subplot(211)
plt.plot(range(12))
plt.subplot(212, facecolor='y') # creates 2nd subplot with yellow background

# %% [markdown]
# Class work: Generate as many insight as you could think of through visuals and other method from iris.csv dataset.
# Time Duration: 1:20 - 3:30pm
#
# Note: Write out your insights in form of a sentence

# %% [markdown]
# ## Visualizations with Seaborn
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# It is pre-installed on Anaconda as matplotlib, NumPy and Pandas are

# %%
import seaborn as sns # Import seaborn

# %%
iris.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
iris['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
iris.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.heatmap(iris.isnull())

# %%
sns.heatmap(iris.corr())

# %%
iris['SepalLengthCm'].hist() #Pandas viz

# %%
iris['Id'].hist() #Pandas viz

# %%
plt.scatter(iris.Id, iris.SepalLengthCm)

# %%
sns.pairplot(data = iris)

# %%
sns.pairplot(data = iris, hue = 'Species')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x = 'Species', y = 'SepalLengthCm', data = iris)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(x= 'Species', data = iris)

# %%
sns.boxplot(x = 'Species', y = 'SepalLengthCm', data = iris)

# %%
sns.distplot(a = iris.PetalLengthCm)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
